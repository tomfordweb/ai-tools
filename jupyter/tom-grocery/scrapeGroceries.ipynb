# %%
# !pip install -r requirements.txt
# !pip install langchain langchain-ollama langchain-openai jupyterlab_flake8
# Out:
# ...
#   Using cached black-25.11.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (85 kB)
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached imutils-0.5.4-py3-none-any.whl
# ...
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached numpy-2.2.6-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#   Using cached opencv_contrib_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# ...
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached pillow-12.0.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# ...
#   Using cached pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached pytokens-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# ...

# %%
import scan_receipt
items = scan_receipt.scan({"directory": "data/mperks-t"})
for item in items:
    print(item)
# Out:
# 4901 PARSLEY
# 4067 ZUCCHINI SQUAS
# 70882031501 SALT
# 85001790100 FRESH MINT
# 7096900344 SHALLOTS
# 5100002548 PASTA SAUCE
# 61126971646 RED BULL 12 0Z
# 71373313110 PASTA
# 4125094882 MEIJER BUTTER
# 4082907787 CAKE DECOR
# 5210007103 VANILLA EXTRAC
# 4125094669 GRANULATD SUGA
# 2022203000005 CAB FLT MIGNON
# 4900000045 DIET COKE
# 4760001136 SEASONING
# 28754500000 LAMB LEG BNLS
# 70882022608 KITCHEN GADGET
# 1440010119 CANNING BOOK
# 70882018495 MJR SELF GRIP
# 7046200791 CANDY
# 71928373046 MEIJER JUICE
# 2700038811 TOMATO PASTE
# 4801 TOMATILLOS
# 2460001086 SALT
# 2840076719 CHEETOS
# 71928349421 PEPPER CORN
# 61126971646 RED BULL 12 0Z
# 71373379790 CINNAMON STICK
# 70882000542 GRANULATD SUGA
# 4125096471 VINEGAR
# 5210000234 CLOVES WHOLE
# 7131404977 BAGEL
# 5210000395 VANILLA BEANS
# 3980011009 BATTERY
# 19305206911 ZURU MAX RETRO
# 19305206912 MAX BRICKS TOY
# 1964950826 ADVENT CALENDA
# 7920006069 NERDS
# 2200001464 CANDY
# 71373381504 MEIJER EGGS
# 1200000159 AQUAFINA
# ...

# %%
import sys
from langchain_ollama import ChatOllama
from langchain_openai import ChatOpenAI
from langchain.messages import AIMessage
from langchain_core.prompts import PromptTemplate
from langchain.messages import HumanMessage, AIMessage, SystemMessage


llm = ChatOpenAI(
    model="mistralai/ministral-3-3b",
    temperature=0.0,  # Or your desired temperature
    base_url="http://127.0.0.1:1234/v1",
    api_key="not-needed"
)

conversation = [
    SystemMessage("You are an expert in grocery store inventory and products sold in grocery stores. You are responsible for reading this list of upc and product abbreviations. Do not make any modifications to the data. Return only rows from the list that are food. Remove drinks and energy drinks."),
    HumanMessage('\n'.join(items)),
]

response = llm.invoke(conversation)
print(response.content)
# Out:
# Here are the rows from your list that contain food products:
#
# - **4901 PARSLEY**
# - **4082907787 CAKE DECOR** *(Note: This is technically a baking ingredient, but often considered part of food items in grocery stores)*
# - **5100002548 PASTA SAUCE**
# - **71373313110 PASTA**
# - **719283823 current (likely a typo for 71928382389) PECAN PIE** *(Assuming this is meant to be "PECAN PIE")*
# - **4610000122 CHEESE SLICES**
# - **4610002046 SLICED CHEESE**
# - **5000042309 KETCHUP** *(Note: This is a condiment, but often included in food categories)*
# - **7274584461 CHICKEN**
# - **7027700006 FETA**
# - **71373372720 MJR CREAM CHS** *(Assuming this is meant to be "MEIJER CREAM CHEESE")*
# - **85004397820 CHEESE**
#
# *Note: Some items like cake decorating and condiments (ketchup, salt) are borderline but included in food categories based on their typical grocery store placement.*
